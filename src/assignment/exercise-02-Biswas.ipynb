# %%
import sys
# Windows and Linux so far have no problem with the inline backend...
if not "win" in sys.platform and not "linux" in sys.platform:
    # %pylab
# ...on other platforms we did run into problems in the past, so let's use the default backend
else:
    # %pylab inline
    
import numpy as np
from sklearn import tree
import os
from IPython.core.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#################################################################
#### Preparing training set #####################################
#################################################################

# loading data from file
li = [i.strip().split(',') for i in open("zoo.data").readlines()]

data = np.array(li)
names = data[:,0]
d = data[:, 1:names.size]

# class defination given in the 'zoo.names' file
class0 = "aardvark, antelope, bear, boar, buffalo, calf,\
cavy, cheetah, deer, dolphin, elephant,\
fruitbat, giraffe, girl, goat, gorilla, hamster,\
hare, leopard, lion, lynx, mink, mole, mongoose,\
opossum, oryx, platypus, polecat, pony,\
porpoise, puma, pussycat, raccoon, reindeer,\
seal, sealion, squirrel, vampire, vole, wallaby,wolf".replace(' ', '').split(',')

class1 = "chicken, crow, dove, duck, flamingo, gull, hawk,\
kiwi, lark, ostrich, parakeet, penguin, pheasant,\
rhea, skimmer, skua, sparrow, swan, vulture, wren".replace(' ', '').split(',')

class2 = "pitviper, seasnake, slowworm, tortoise, tuatara".replace(' ', '').split(',')
class3 = "bass, carp, catfish, chub, dogfish, haddock,\
herring, pike, piranha, seahorse, sole, stingray, tuna".replace(' ', '').split(',')
class4 = "frog, frog, newt, toad".replace(' ', '').split(',')
class5 = "flea, gnat, honeybee, housefly, ladybird, moth, termite, wasp".replace(' ', '').split(',')
class6 = "clam, crab, crayfish, lobster, octopus,\
scorpion, seawasp, slug, starfish, worm".replace(' ', '').split(',')


labels = []
for name in names:
    if name in class0:
        labels.append(0)
    elif name in class1:
        labels.append(1)
    elif name in class2:
        labels.append(2)
    elif name in class3:
        labels.append(3)
    elif name in class4:
        labels.append(4)
    elif name in class5:
        labels.append(5)
    elif name in class6:
        labels.append(6)

features = zeros(d.shape)
for i in range(features.shape[0]):
    for j in range(features.shape[1]):
        features[i,j] = int(d[i,j])

# %%
labels = np.array(labels).reshape(size(features,0),1)
features = np.hstack((labels, features))
print features.shape
# Out:
# (101, 18)

# %% [markdown]
# ### 7. 1) predicting attribute 18 (type) from attributes 2 to 17

# %%
features1 = features[:,1:16]
targets1 = features[:,17]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


os.system("dot -Tpng 7_1.dot -o 7_1.png")
os.unlink('7_1.dot')
Image(filename='7_1.png')

# %% [markdown]
# ### 7.2) predicting attribute 18 (type) from attributes 1 to 17

# %%
features1 = features[:,0:16]
targets1 = features[:,17]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


os.system("dot -Tpng 7_1.dot -o 7_1.png")
os.unlink('7_1.dot')
Image(filename='7_1.png')

# %% [markdown]
# ### 7.3) predicting attribute 6 (airborne) from attributes 2 to 5 and 7 to 18

# %%
features1 = np.hstack((features[:,1:4], features[:, 6:17]))
targets1 = features[:,5]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


os.system("dot -Tpng 7_1.dot -o 7_1.png")
os.unlink('7_1.dot')
Image(filename='7_1.png')

# %% [markdown]
# ### 7.4) predicting attribute 1 (animal) from attributes 2 to 18

# %%
features1 = features[:,1:17]
targets1 = features[:,0]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


os.system("dot -Tpng 7_1.dot -o 7_1.png")
os.unlink('7_1.dot')
Image(filename='7_1.png')

# %% [markdown]
# ### Ex 8.1) code run for < 3 minutes

# %%
li = [i.strip().split(',') for i in open("letter-recognition.data").readlines()]

data = np.array(li)
labels = data[:,0]
d = data[:, 1:labels.size]

features = zeros(d.shape)
for i in range(features.shape[0]):
    for j in range(features.shape[1]):
        features[i,j] = int(d[i,j])
        
labels = np.array(labels).reshape(size(labels,0),1)
print labels.shape
print features.shape
# Out:
# (20000, 1)
# (20000, 16)

# %%
no_of_examples = 2000
features1 = features[0:no_of_examples-1, :]
targets1 = labels[0:no_of_examples-1, :]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


#os.system("dot -Tpng 7_1.dot -o 7_1.png")
#os.unlink('7_1.dot')
#Image(filename='7_1.png')
print 'learnt classes', clf1.tree_.n_classes
print 'total number of nodes in the tree', clf1.tree_.node_count


examples = []
nodes = []
examples.append(no_of_examples)
nodes.append(clf1.tree_.node_count)
# Out:
# learnt classes [26]
# total number of nodes in the tree 879

# %% [markdown]
# ### 8.2)

# %%
no_of_examples = 5000
features1 = features[0:no_of_examples-1, :]
targets1 = labels[0:no_of_examples-1, :]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


#os.system("dot -Tpng 7_1.dot -o 7_1.png")
#os.unlink('7_1.dot')
#Image(filename='7_1.png')
print 'learnt classes', clf1.tree_.n_classes
print 'total number of nodes in the tree', clf1.tree_.node_count
examples.append(no_of_examples)
nodes.append(clf1.tree_.node_count)
# Out:
# learnt classes [26]
# total number of nodes in the tree 1677

# %%
no_of_examples = 8000
features1 = features[0:no_of_examples-1, :]
targets1 = labels[0:no_of_examples-1, :]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


#os.system("dot -Tpng 7_1.dot -o 7_1.png")
#os.unlink('7_1.dot')
#Image(filename='7_1.png')
print 'learnt classes', clf1.tree_.n_classes
print 'total number of nodes in the tree', clf1.tree_.node_count
examples.append(no_of_examples)
nodes.append(clf1.tree_.node_count)
# Out:
# learnt classes [26]
# total number of nodes in the tree 2267

# %%
no_of_examples = 15000
features1 = features[0:no_of_examples-1, :]
targets1 = labels[0:no_of_examples-1, :]

clf1 = tree.DecisionTreeClassifier(criterion='entropy', splitter='best',\
max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None,\
random_state=None, min_density=None, compute_importances=None)

clf1 = clf1.fit(features1, targets1)

with open("7_1.dot", 'w') as f:
    f = tree.export_graphviz(clf1, out_file=f)


#os.system("dot -Tpng 7_1.dot -o 7_1.png")
#os.unlink('7_1.dot')
#Image(filename='7_1.png')
print 'learnt classes', clf1.tree_.n_classes
print 'total number of nodes in the tree', clf1.tree_.node_count
examples.append(no_of_examples)
nodes.append(clf1.tree_.node_count)
# Out:
# learnt classes [26]
# total number of nodes in the tree 3487

# %%
print examples
print nodes
plot(examples, nodes)
xlabel("no_of_examples")
ylabel("no_of_nodes")
# Out:
# [2000, 5000, 8000, 15000]
# [879, 1677, 2267, 3487]

# %% [markdown]
# ## Hence, with increase of training examples no of nodes are increasing but this rate of increase is getting lesser with increasing number of examples.
